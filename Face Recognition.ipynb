# %% [markdown]
# # FACE RECOGNITION MODEL

# %% [markdown]
# # #import libraries

# %%
import os                           #for seemeless intraction with os
import warnings
warnings.simplefilter('ignore')     #to ignore warning message

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
# %matplotlib inline

from skimage.io import imread,imshow
from skimage.transform import resize       #Image Reading,Transform,Colorchange
from skimage.color import rgb2gray

# %%
Shahruk= os.listdir("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Shahrukhkhan Face")

# %%
hemsworth=os.listdir("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Chris Hemsworth Face")

# %%
elizabeth=os.listdir("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Elizabeth Olsen Face")

# %%
limit=50
Shahruk_image= [None]*limit
j=0

for i in Shahruk:
    if(j<limit):
      Shahruk_image[j]=imread("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Shahrukhkhan Face/"+i)
      j+=1  
    else:
        break

# %%
limit=50
hemsworth_image= [None]*limit
j=0

for i in hemsworth:
    if(j<limit):
      hemsworth_image[j]=imread("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Chris Hemsworth Face/"+i)
      j+=1  
    else:
        break

# %%
limit=50
elizabeth_image= [None]*limit
j=0

for i in elizabeth:
    if(j<limit):
      elizabeth_image[j]=imread("C:/Users/balvi/Documents/Untitled Folder/Photo Data/Elizabeth Olsen Face/"+i)
      j+=1  
    else:
        break

# %%
imshow(elizabeth_image[0])

# %%
imshow(hemsworth_image[0])

# %%
imshow(Shahruk_image[0])

# %%
Shahruk_grey=[None]*limit
j=0

for i in Shahruk:
    if(j<limit):
        Shahruk_grey[j]=rgb2gray(Shahruk_image[j])
        j+=1
    else:
        break

# %%
elizabeth_grey=[None]*limit
j=0

for i in elizabeth:
    if(j<limit):
        elizabeth_grey[j]=rgb2gray(elizabeth_image[j])
        j+=1
    else:
        break

# %%
hemsworth_grey=[None]*limit
j=0

for i in hemsworth:
    if(j<limit):
        hemsworth_grey[j]=rgb2gray(hemsworth_image[j])
        j+=1
    else:
        break

# %%
imshow(Shahruk_grey[1])

# %%
imshow(elizabeth_grey[1])

# %%
imshow(hemsworth_grey[1])

# %%
Shahruk_grey[1].shape
# Out:
# (2121, 1527)

# %%
Shahruk_grey[3].shape
# Out:
# (976, 691)

# %%
Shahruk_grey[2].shape
# Out:
# (720, 600)

# %% [markdown]
# # Image Resizing

# %%
for j in  range(50):
    ch=Shahruk_grey[j]
    Shahruk_grey[j]=resize(ch,(800,800))

# %%
for j in  range(50):
    ch=elizabeth_grey[j]
    elizabeth_grey[j]=resize(ch,(800,800))

# %%
for j in  range(50):
    ch=hemsworth_grey[j]
    hemsworth_grey[j]=resize(ch,(800,800))

# %%
imshow(Shahruk_grey[2])

# %%
imshow(elizabeth_grey[2])

# %%
imshow(hemsworth_grey[2])

# %% [markdown]
# # matrix to vector convertion

# %%
len_of_images_Shahruk=len(Shahruk_grey)
len_of_images_Shahruk
# Out:
# 50

# %%
len_of_images_elizabeth=len(elizabeth_grey)
len_of_images_elizabeth
# Out:
# 50

# %%
len_of_images_hemsworth=len(hemsworth_grey)
len_of_images_hemsworth
# Out:
# 50

# %%
image_size_Shahruk=Shahruk_grey[1].shape

# %%
image_size_Shahruk
# Out:
# (800, 800)

# %%
image_size_elizabeth=elizabeth_grey[1].shape

# %%
image_size_elizabeth
# Out:
# (800, 800)

# %%
image_size_hemsworth=hemsworth_grey[1].shape

# %%
image_size_hemsworth
# Out:
# (800, 800)

# %% [markdown]
# # Flattening

# %%
flatten_size_Shahruk = image_size_Shahruk[0]*image_size_Shahruk[1]
flatten_size_Shahruk
# Out:
# 640000

# %%
for i in range(len_of_images_Shahruk):
    Shahruk_grey[i]=np.ndarray.flatten(Shahruk_grey[i]).reshape(flatten_size_Shahruk,1)

# %%
Shahruk_grey=np.dstack(Shahruk_grey)

# %%
Shahruk_grey=np.rollaxis(Shahruk_grey,axis=2,start=0)
Shahruk_grey.shape
# Out:
# (50, 640000, 1)

# %%
Shahruk_grey=Shahruk_grey.reshape(len_of_images_Shahruk,flatten_size_Shahruk)

# %%
Shahruk_grey.shape
# Out:
# (50, 640000)

# %%
flatten_size_elizabeth = image_size_elizabeth[0]*image_size_elizabeth[1]
flatten_size_elizabeth
# Out:
# 640000

# %%
for i in range(len_of_images_elizabeth):
    elizabeth_grey[i]=np.ndarray.flatten(elizabeth_grey[i]).reshape(flatten_size_elizabeth,1)

# %%
elizabeth_grey=np.dstack(elizabeth_grey)

# %%
elizabeth_grey=np.rollaxis(elizabeth_grey,axis=2,start=0)
elizabeth_grey.shape
# Out:
# (50, 640000, 1)

# %%
elizabeth_grey=elizabeth_grey.reshape(len_of_images_elizabeth,flatten_size_elizabeth)

# %%
elizabeth_grey.shape
# Out:
# (50, 640000)

# %%
flatten_size_hemsworth = image_size_hemsworth[0]*image_size_hemsworth[1]
flatten_size_hemsworth
# Out:
# 640000

# %%
for i in range(len_of_images_hemsworth):
    hemsworth_grey[i]=np.ndarray.flatten(hemsworth_grey[i]).reshape(flatten_size_hemsworth,1)

# %%
  hemsworth_grey=np.dstack(hemsworth_grey)

# %%
hemsworth_grey=np.rollaxis(hemsworth_grey,axis=2,start=0)
hemsworth_grey.shape
# Out:
# (50, 640000, 1)

# %%
hemsworth_grey=hemsworth_grey.reshape(len_of_images_hemsworth,flatten_size_hemsworth)

# %%
hemsworth_grey.shape
# Out:
# (50, 640000)

# %% [markdown]
# # Dataframe of the image vectors

# %%
Shahruk_data=pd.DataFrame(Shahruk_grey)

# %%
Shahruk_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.079526  0.080124  0.078462  0.076800  0.075139  0.073477  0.071815
# 1   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2   0.401280  0.399417  0.398447  0.399055  0.398430  0.399848  0.403243
# 3   0.011765  0.011765  0.011765  0.011765  0.011765  0.011765  0.011765
# 4   0.156863  0.156863  0.156863  0.156863  0.156863  0.156863  0.156863
# 5   0.848656  0.852642  0.855024  0.851140  0.849376  0.857286  0.864935
# 6   0.988764  0.988764  0.988764  0.988769  0.988781  0.988781  0.988781
# 7   0.834668  0.836109  0.844218  0.852709  0.861317  0.866625  0.871438
# 8   0.350446  0.350446  0.350446  0.348539  0.346735  0.348961  0.351186
# 9   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 10  0
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.094118  0.094118  0.094118  0.094118  0.094118  0.094118  0.094118
# 1   0.498121  0.490116  0.493151  0.487054  0.484121  0.483587  0.491889
# 2   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 3   0.093537  0.093537  0.093537  0.094645  0.097459  0.097459  0.097459
# 4   0.945780  0.945780  0.945780  0.945780  0.945780  0.945780  0.942564
# ..       ...       ...       ...       ...       ...       ...       ...
# 45  0.646035  0.648853  0.651670  0.652104  0.649286  0.646468  0.643650
# 46  0.364320  0.363948  0.361801  0.359654  0.357506  0.355725  0.354116
# 47  0.956561  0.956169  0.954012  0.951855  0.949698  0.951659  0.954110
# 48  0.051789  0.057889  0.051835  0.045735  0.039635  0.035239  0.030863
# 49  0.514146  0.514035  0.513924  0.513812  0.513900  0.514012  0.514123
#
#            7         8         9  ...    639991    639992    639993    639994  \
# ...

# %%
from sklearn.utils import shuffle

# %%
sh=shuffle(final_list).reset_index()

# %%
sh
# Out:
#      index         0         1         2         3         4         5  \
# 0        8  0.651863  0.650765  0.650765  0.648106  0.646844  0.645622
# 1        0  0.133378  0.133378  0.133378  0.133378  0.133378  0.133378
# 2        7  0.834668  0.836109  0.844218  0.852709  0.861317  0.866625
# 3        1  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 4       46  0.364320  0.363948  0.361801  0.359654  0.357506  0.355725
# ..     ...       ...       ...       ...       ...       ...       ...
# 145     23  0.361619  0.361893  0.357051  0.351844  0.346124  0.340403
# 146     30  0.600703  0.600565  0.601643  0.603136  0.605559  0.608051
# 147     48  0.166142  0.166142  0.166020  0.163618  0.162221  0.162221
# 148     24  0.441304  0.440354  0.444629  0.448961  0.453576  0.458190
# 149      0  0.079526  0.080124  0.078462  0.076800  0.075139  0.073477
#
#             6         7         8  ...    639991    639992    639993  \
# ...

# %%
sh=sh.drop(["index"],axis=1)

# %%
sh
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.651863  0.650765  0.650765  0.648106  0.646844  0.645622  0.646638
# 1    0.133378  0.133378  0.133378  0.133378  0.133378  0.133378  0.133378
# 2    0.834668  0.836109  0.844218  0.852709  0.861317  0.866625  0.871438
# 3    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 4    0.364320  0.363948  0.361801  0.359654  0.357506  0.355725  0.354116
# ..        ...       ...       ...       ...       ...       ...       ...
# 145  0.361619  0.361893  0.357051  0.351844  0.346124  0.340403  0.334682
# 146  0.600703  0.600565  0.601643  0.603136  0.605559  0.608051  0.610861
# 147  0.166142  0.166142  0.166020  0.163618  0.162221  0.162221  0.162221
# 148  0.441304  0.440354  0.444629  0.448961  0.453576  0.458190  0.455113
# 149  0.079526  0.080124  0.078462  0.076800  0.075139  0.073477  0.071815
#
#             7         8         9  ...    639991    639992    639993  \
# ...

# %%
x=sh.values[:,:-1]

# %%
x
# Out:
# array([[0.651862887346407, 0.6507650980392158, 0.6507650980392158, ...,
#         0.5846668892325659, 0.5874474569970363, 0.5885854901960785],
#        [0.13337803921076952, 0.13337803921076952, 0.13337803921076952,
#         ..., 0.2534494121259364, 0.2695816464694103, 0.2727540555125744],
#        [0.8346682674632354, 0.836109021139706, 0.844217878370098, ...,
#         0.2671839093137255, 0.2671839093137255, 0.2671839093137255],
#        ...,
#        [0.1661423529411765, 0.1661423529411765, 0.16601980392156868, ...,
#         0.11572796894148515, 0.12519681728707124, 0.12837262748927664],
#        [0.44130426470588235, 0.44035426470588235, 0.4446292647058823,
#         ..., 0.41832901960784313, 0.41832901960784313,
#         0.41832901960784313],
#        [0.07952578431372548, 0.08012382352941175, 0.07846205882352941,
#         ..., 0.11143990196078432, 0.10811637254901973,
#         0.10931245098039254]], dtype=object)

# %%
y=sh.values[:,-1]

# %%
y
# Out:
# array(['CHRIS HEMSWORTH', 'ELIZABETH OLSEN', 'Shahruk', 'Shahruk',
#        'Shahruk', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH', 'ELIZABETH OLSEN',
#        'Shahruk', 'CHRIS HEMSWORTH', 'CHRIS HEMSWORTH', 'ELIZABETH OLSEN',
#        'ELIZABETH OLSEN', 'CHRIS HEMSWORTH', 'ELIZABETH OLSEN', 'Shahruk',
#        'Shahruk', 'Shahruk', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH',
#        'Shahruk', 'Shahruk', 'ELIZABETH OLSEN', 'Shahruk',
#        'CHRIS HEMSWORTH', 'ELIZABETH OLSEN', 'Shahruk', 'CHRIS HEMSWORTH',
#        'Shahruk', 'ELIZABETH OLSEN', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH',
#        'CHRIS HEMSWORTH', 'ELIZABETH OLSEN', 'ELIZABETH OLSEN',
#        'ELIZABETH OLSEN', 'Shahruk', 'Shahruk', 'CHRIS HEMSWORTH',
#        'ELIZABETH OLSEN', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH',
#        'CHRIS HEMSWORTH', 'Shahruk', 'Shahruk', 'ELIZABETH OLSEN',
#        'Shahruk', 'CHRIS HEMSWORTH', 'Shahruk', 'ELIZABETH OLSEN',
#        'ELIZABETH OLSEN', 'CHRIS HEMSWORTH', 'ELIZABETH OLSEN',
# ...

# %% [markdown]
# # Module_selection

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
from sklearn import svm

# %%
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Shahruk', 'Shahruk', 'CHRIS HEMSWORTH', 'CHRIS HEMSWORTH',
#        'ELIZABETH OLSEN', 'CHRIS HEMSWORTH', 'ELIZABETH OLSEN',
#        'ELIZABETH OLSEN', 'ELIZABETH OLSEN', 'Shahruk', 'CHRIS HEMSWORTH',
#        'CHRIS HEMSWORTH', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH', 'Shahruk',
#        'ELIZABETH OLSEN', 'ELIZABETH OLSEN', 'CHRIS HEMSWORTH',
#        'ELIZABETH OLSEN', 'Shahruk', 'Shahruk', 'Shahruk',
#        'CHRIS HEMSWORTH', 'Shahruk', 'ELIZABETH OLSEN', 'ELIZABETH OLSEN',
#        'Shahruk', 'ELIZABETH OLSEN', 'ELIZABETH OLSEN', 'Shahruk'],
#       dtype=object)

# %% [markdown]
# # prediction accuracy

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8333333333333334

# %% [markdown]
# # error analysis of prediction

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 6,  1,  1],
#        [ 2, 10,  0],
#        [ 0,  1,  9]], dtype=int64)
